# %% [markdown]
# # Wine

# %% [markdown]
# ### Introduction:
#
# This exercise is a adaptation from the UCI Wine dataset.
# The only pupose is to practice deleting data with pandas.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data).

# %% [markdown]
# ### Step 3. Assign it to a variable called wine

# %%
wine = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data', header=None)

# %% [markdown]
# ### Step 4. Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns

# %%
wine = wine.drop([0, 3, 6, 8, 10, 12, 13], axis=1)
wine.head()
# Out:
#       1     2     4    5     7     9     11
# 0  14.23  1.71  15.6  127  3.06  2.29  1.04
# 1  13.20  1.78  11.2  100  2.76  1.28  1.05
# 2  13.16  2.36  18.6  101  3.24  2.81  1.03
# 3  14.37  1.95  16.8  113  3.49  2.18  0.86
# 4  13.24  2.59  21.0  118  2.69  1.82  1.04

# %% [markdown]
# ### Step 5. Assign the columns as below:
#
# The attributes are (donated by Riccardo Leardi, riclea '@' anchem.unige.it):
# 1) alcohol
# 2) malic_acid
# 3) alcalinity_of_ash
# 4) magnesium
# 5) flavanoids
# 6) proanthocyanins
# 7) hue

# %%
wine.columns = ['alcohol', 'malic_acid', 'alcalinity_of_ash', 'magnesium', 'flavanoids', 'proanthocyanins', 'hue']
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    14.23        1.71               15.6        127        3.06
# 1    13.20        1.78               11.2        100        2.76
# 2    13.16        2.36               18.6        101        3.24
# 3    14.37        1.95               16.8        113        3.49
# 4    13.24        2.59               21.0        118        2.69
#
#    proanthocyanins   hue
# 0             2.29  1.04
# 1             1.28  1.05
# 2             2.81  1.03
# 3             2.18  0.86
# 4             1.82  1.04

# %% [markdown]
# ### Step 6. Set the values of the first 3 rows from alcohol as NaN

# %%
wine.loc[0:2, 'alcohol'] = np.nan

# %% [markdown]
# ### Step 7. Now set the value of the rows 3 and 4 of magnesium as NaN

# %%
wine.loc[2:3, 'magnesium'] = np.nan

# %% [markdown]
# ### Step 8. Fill the value of NaN with the number 10 in alcohol and 100 in magnesium

# %%
wine['alcohol'] = wine['alcohol'].fillna(10)
wine['magnesium'] = wine['magnesium'].fillna(100)

# %% [markdown]
# ### Step 9. Count the number of missing values

# %%
wine.isnull().sum()
# Out:
# alcohol              0
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            0
# flavanoids           0
# proanthocyanins      0
# hue                  0
# dtype: int64

# %% [markdown]
# ### Step 10.  Create an array of 10 random numbers up until 10

# %%
random_index = np.random.randint(0, 10, size=10)
print("Random indices:", random_index)
# Out:
# Random indices: [5 7 8 6 2 6 5 2 9 7]

# %% [markdown]
# ### Step 11.  Use random numbers you generated as an index and assign NaN value to each of cell.

# %%
wine.loc[random_index, 'hue'] = np.nan

# %% [markdown]
# ### Step 12.  How many missing values do we have?

# %%
wine.isnull().sum()
# Out:
# alcohol              0
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            0
# flavanoids           0
# proanthocyanins      0
# hue                  6
# dtype: int64

# %% [markdown]
# ### Step 13. Delete the rows that contain missing values

# %%
wine = wine.dropna(how='any')
print(f"Rows remaining: {len(wine)}")
# Out:
# Rows remaining: 172

# %% [markdown]
# ### Step 14. Print only the non-null values in alcohol

# %%
wine['alcohol'].head(10)
# Out:
# 0     10.00
# 1     10.00
# 3     14.37
# 4     13.24
# 10    14.10
# 11    14.12
# 12    13.75
# 13    14.75
# 14    14.38
# 15    13.63
# Name: alcohol, dtype: float64

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 172 entries, 0 to 177
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   alcohol            172 non-null    float64
#  1   malic_acid         172 non-null    float64
#  2   alcalinity_of_ash  172 non-null    float64
#  3   magnesium          172 non-null    float64
#  4   flavanoids         172 non-null    float64
#  5   proanthocyanins    172 non-null    float64
#  6   hue                172 non-null    float64
# dtypes: float64(7)
# memory usage: 10.8 KB

# %% [markdown]
# ### Step 15.  Reset the index, so it starts with 0 again

# %%
wine = wine.reset_index(drop=True)
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    10.00        1.71               15.6      127.0        3.06
# 1    10.00        1.78               11.2      100.0        2.76
# 2    14.37        1.95               16.8      100.0        3.49
# 3    13.24        2.59               21.0      118.0        2.69
# 4    14.10        2.16               18.0      105.0        3.32
#
#    proanthocyanins   hue
# 0             2.29  1.04
# 1             1.28  1.05
# 2             2.18  0.86
# 3             1.82  1.04
# 4             2.38  1.25

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
# Question: What is the average value of each column after all data cleaning?
print("Average values after cleaning:")
print(wine.mean())
# Out:
# Average values after cleaning:
# alcohol              12.919651
# malic_acid            2.353140
# alcalinity_of_ash    19.616860
# magnesium            99.511628
# flavanoids            1.996628
# proanthocyanins       1.577558
# hue                   0.954512
# dtype: float64
